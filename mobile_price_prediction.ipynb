# %% [markdown]
# <a href="https://colab.research.google.com/github/OmashV/Mobile_Price_Prediction/blob/main/mobile_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/mobile_price.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
x = df.drop('price_range', axis=1)
y = df['price_range']
print(y)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1995    0
# 1996    0
# 1997    1
# 1998    0
# 1999    1
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from keras.models import Sequential,load_model
from keras.layers import Dense,Dropout

# %%
model = Sequential()
model.add(Dense(8,input_dim= len(x_train.columns),activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='sgd',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=100,batch_size=32,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4853 - loss: 57.0715 - val_accuracy: 0.4980 - val_loss: 0.6932
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4906 - loss: 0.6933 - val_accuracy: 0.4980 - val_loss: 0.6932
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4811 - loss: 0.6934 - val_accuracy: 0.4980 - val_loss: 0.6932
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5128 - loss: 0.6930 - val_accuracy: 0.4980 - val_loss: 0.6932
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4963 - loss: 0.6932 - val_accuracy: 0.4980 - val_loss: 0.6932
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5139 - loss: 0.6930 - val_accuracy: 0.4980 - val_loss: 0.6932
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4791 - loss: 0.6934 - val_accuracy: 0.4980 - val_loss: 0.6932
# Epoch 8/100
# ...

# %%
model.save('mobile_price.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
